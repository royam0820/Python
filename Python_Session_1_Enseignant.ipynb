# %% [markdown]
# <a href="https://colab.research.google.com/github/royam0820/Python/blob/main/Python_Session_1_Enseignant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 1 : Premiers pas avec Python et Google Colab 🐍
#
# Bienvenue dans notre aventure de camp d'été sur Python et l'IA ! Aujourd'hui, nous allons apprendre les bases de Python et comment utiliser Google Colab, un outil super cool qui nous permet de coder dans le cloud. C'est parti ! 🚀
#
# Sujets couverts
# - la fonction print
# - les variables
# - les mathèmatiques de base
# - la function input
#
# et quelques activités sur ces thèmes
#
# ---

# %% [markdown]
# ## 1. Qu'est-ce que Python ?
# Python est un langage de programmation utilisé pour dire aux ordinateurs quoi faire. Il est facile à apprendre et alimente des choses comme les jeux, les applications et même l'intelligence artificielle (IA) ! Saviez-vous que Python est nommé d'après une émission comique appelée "Monty Python", pas le serpent ? 😄
#
# ![python_comedy_show.png](data:image/png;base64,...)
#
# ### Essayez-le !
# Exécutez le code ci-dessous en cliquant sur le bouton "Play" (▶️) à côté. Il dira bonjour au monde !

# %%
print("Bonjour, le monde !")
# Out:
# Bonjour, le monde !

# %% [markdown]
# ## 2. Découvrez Google Colab
# Google Colab est comme un cahier magique où nous pouvons écrire et exécuter du code Python en ligne. Vous n'avez rien à installer, il suffit de l'ouvrir dans votre navigateur !
#
# ### Comment l'utiliser :
# - **Cellules de code** : Cases où vous écrivez du code Python (comme celle ci-dessus). shortcut : control + M + B
# - **Cellules de texte** : Cases comme celle-ci pour les explications. shortcut : control + M + T
# - **Exécuter le code** : Cliquez sur le bouton ▶️ pour faire fonctionner le code.
# - **Enregistrer** : Colab enregistre automatiquement votre travail sur votre Google Drive.
#
# Pratiquons l'exécution du code ensemble !

# %% [markdown]
# ## 3. Les bases de Python
#
# ### Instructions d'impression
# Nous utilisons `print()` pour afficher des messages ou des nombres à l'écran.

# %%
print("J'adore coder !")
print(42)
print(42+3)
# Out:
# J'adore coder !
# 42
# 45

# %% [markdown]
# ### Variables et types de données
# Les variables sont comme des boîtes qui contiennent des informations. Elles peuvent stocker :
# - **Chaînes de caractères** (string) : Mots ou texte (par exemple, `"Bonjour"`).
# - **Entiers** (integer) : Nombres entiers (par exemple, `10`).
# - **Flottants** (float) : Nombres avec des décimales (par exemple, `3.14`).
# - **Bouléens** (Boolean): Vrai ou Faux (True ou False)

# %%
# Exemples
nom = "Alex"  # Chaîne de caractères - string
age = 12      # Entier - integer
taille = 1.42  # Flottant - float
est_jeune = True  # bouléen

print(nom)
print(age)
print(taille)
print(est_jeune)
# Out:
# Alex
# 12
# 1.42
# True

# %% [markdown]
# > 🤖 **Demande à l'IA** :
#
# > ➡️ d'imprimer sur une ligne l'instruction suivante: je m'appelle (nom), j'ai (age) ans, et ma taille est de (taille)**

# %%
# prompt: imprime sur une ligne l'instruction suivante: je m'appelle (nom), j'ai (age) ans, et ma taille est de (taille)

nom = "Alex"  # Chaîne de caractères - string
age = 12      # Entier - integer
taille = 1.42  # Flottant - float

print(f"Je m'appelle {nom}, j'ai {age} ans, et ma taille est de {taille} m")
# Out:
# Je m'appelle Alex, j'ai 12 ans, et ma taille est de 1.42 m

# %% [markdown]
# NB: Noter l'instruction print généré,
# - `print(f"Je m'appelle {nom}, j'ai {age} ans, et ma taille est de {taille}")`
#
# Python utilise la lettre `f` ou `F`, dans laquelle on peut inclure des expressions Python entre accolades {}. Ces expressions sont évaluées au moment de l’exécution, et leur valeur est automatiquement insérée dans la chaîne.
#
# Dans notre exemple ;
# - Les variables entourés d'accolades `{..} vont être résolues au moment de l'instruction d'impression, par exemple ;
# - {nom} → sera remplacée par "Alex"
# - {age} → sera remplacée par 12
# - {taille} → sera remplacée par 1.42

# %%
# une variable a un type de données, l'instruction type vous donne cette information
type(nom)
# Out:
# str

# %% [markdown]
# >🤖 **Demande à l'IA**:
#
# > ➡️ types de données dans Python, donne moi les principaux **types**

# %%
# prompt: types de données dans Python, donne moi les principaux types

# Types de données principaux en Python

# 1. Nombres entiers (int)
entier = 10
print(entier, type(entier))  # Affiche <class 'int'>

# 2. Nombres à virgule flottante (float)
flottant = 3.14
print(flottant, type(flottant))  # Affiche <class 'float'>

# 3. Chaînes de caractères (str)
chaine = "Bonjour le monde !"
print(chaine, type(chaine))  # Affiche <class 'str'>

# 4. Booléens (bool)
booleen_vrai = True
booleen_faux = False
print(booleen_vrai, type(booleen_vrai))  # Affiche <class 'bool'>

# 5. Listes (list) - collections ordonnées et modifiables
liste = [1, 2, 3, "a", "b"]
print(liste, type(liste))  # Affiche <class 'list'>

# 6. Tuples (tuple) - collections ordonnées et immuables
tuple_ex = (1, 2, 3, "a", "b")
print(tuple_ex, type(tuple_ex)) # Affiche <class 'tuple'>

# 7. Dictionnaires (dict) - collections de paires clé-valeur
dictionnaire = {"nom": "Alice", "age": 30}
print(dictionnaire, type(dictionnaire)) # Affiche <class 'dict'>

# 8. Ensembles (set) - collections non ordonnées d'éléments uniques
ensemble = {1, 2, 2, 3}  # L'élément 2 est présent une seule fois
print(ensemble, type(ensemble)) # Affiche <class 'set'>
# Out:
# 10 <class 'int'>
# 3.14 <class 'float'>
# Bonjour le monde ! <class 'str'>
# True <class 'bool'>
# [1, 2, 3, 'a', 'b'] <class 'list'>
# (1, 2, 3, 'a', 'b') <class 'tuple'>
# {'nom': 'Alice', 'age': 30} <class 'dict'>
# {1, 2, 3} <class 'set'>

# %% [markdown]
# NB: clavier AZERTY, la combinaison de ces touches clavier donne les résultats suivants :
#
# - option + shift + 5 donne des crochets `[]`
# - option + 5 donne des accolades `{}`
#
# Essayez ces combinaisons de touches dans la cellulule de code ci-après.

# %% [markdown]
# NB: `type()` est une fonction intégrée en Python qui retourne le type d’un objet donné.
#
# C’est comme une étiquette qui dit à Python : “Ceci est un nombre”, “Ceci est une phrase”, ou “Ceci est une liste”. On peut demander à Python : “De quel type est cet objet ?” et il nous répond grâce à type().
#
# Durant ce cours nous verrons ces différents types d'objet.

# %% [markdown]
# ### Mathématiques de base
# Python peut faire des calculs comme une calculatrice ! Utilisez ces symboles :
# - `+` pour l'addition
# - `-` pour la soustraction
# - `*` pour la multiplication
# - `/` pour la division
# - `**`pour l'exposant
# - `//`division entière
# - `%` Modulo, reste de la division

# %%
# Essayez quelques calculs
print(5 + 3)   # Addition
print(10 * 2)  # Multiplication
print(10 / 3)  # Division
print(10 // 3) # Division entière
print(10 % 3)  # Modulo, ce qui reste après avoir divisé 10 par 3
# Out:
# 8
# 20
# 3.3333333333333335
# 3
# 1

# %% [markdown]
# #### Formatage des chiffres décimaux

# %%
# formater un résultat décimal à deux chiffres après la virgule - deux exemples
print(f"{10/3:.2f}")  # ex 1
print(round(10/3, 2)) # ex 2
# Out:
# 3.33
# 3.33

# %%
# arrondir un résultat décimal
nombre1 = 4.7890
print(round(nombre1))
nombre2 = 3.3452
print(round(nombre2))
# Out:
# 5
# 3

# %% [markdown]
# > NB : **Opérations de base sur les nombres**
#
# > La multiplication et la division sont toujours effectuées avant l’addition et la soustraction.

# %%
# Opération de base sur les nombres; Evaluez ces expressions ci-dessous !
print(7 + 7 / 7 + 7 * 7 - 7)
print(5 + 30 * 20)
# Out:
# 50.0
# 605

# %% [markdown]
# > 🤖 **Demande à l'IA** :
#
# > ➡️ donne moi les règles de calcul dans Python

# %%
# prompt: donne moi les règles de calcul dans Python

# Exemple 1 : Parenthèses prioritaires
resultat = (10 + 5) * 2  # (10 + 5) est évalué en premier, puis multiplié par 2
print(resultat)  # Affiche 30

# Exemple 2 : Exposant avant multiplication
resultat = 2 ** 3 * 2  # 2 ** 3 (2 à la puissance 3) est évalué en premier, puis multiplié par 2
print(resultat)  # Affiche 16

# Exemple 3 : Multiplication avant addition
resultat = 5 + 3 * 2  # 3 * 2 est évalué en premier, puis ajouté à 5
print(resultat)  # Affiche 11

# Exemple 4 : Division et multiplication de gauche à droite
resultat = 10 / 2 * 5  # 10 / 2 est évalué en premier (5), puis multiplié par 5
print(resultat)  # Affiche 25

# Exemple 5 : Division entière
resultat = 10 // 3
print(resultat) # Affiche 3

# Exemple 6: Modulo (reste de la division)
resultat = 10 % 3
print(resultat) # Affiche 1


# Utilisation de parenthèses pour contrôler l'ordre
resultat = 10 / (2 * 5) # Ici, (2 * 5) est évalué en premier
print(resultat)  # Affiche 1.0

# %% [markdown]
# #### Règles de Calcul - PEMDAS
# - Parenthèses
# - Exposants
# - Multiplication
# - Division
# - Addition
# - Soustraction
#
# Un bon memotechnique : **"Please Excuse My Dear
# Aunt Sally"**

# %% [markdown]
# ### La Fonction Input
# La fonction `input()` permet à un programme de demander une information à l’utilisateur. Elle affiche un message à l’écran (facultatif), attend que l’utilisateur saisisse du texte, puis retourne ce texte sous forme de chaîne de caractères (str).

# %%
nom = input("Quel est ton prénom ? ")
print("Bonjour " + nom + " !")
# Out:
# Quel est ton prénom ? Alice
# Bonjour Alice !

# %% [markdown]
# Essayez ce code amusant !

# %%
nom = input("Quel est ton prénom ? ")
pouvoir = input("Quel super-pouvoir aimerais-tu avoir ? ")

print("🚀 Attention, " + nom + " se transforme en Super-" + nom.upper() + " avec le pouvoir de " + pouvoir + " !")
print("Le monde n'est plus le même depuis son arrivée... 😎")
# Out:
# Quel est ton prénom ? Alice
# Quel super-pouvoir aimerais-tu avoir ? parler aux animaux
# 🚀 Attention, Alice se transforme en Super-ALICE avec le pouvoir de parler aux animaux !
# Le monde n'est plus le même depuis son arrivée... 😎

# %% [markdown]
# ## 4. Activités

# %% [markdown]
# ### Activité 1 : Imprimez votre nom et votre âge
# Modifiez le code ci-dessous pour imprimer votre nom et votre âge. Remplacez "VotreNom" et 0 par vos vraies informations !

# %%
nom = "VotreNom"  # Changez ceci en votre nom
age = 0           # Changez ceci en votre âge
print("Je m'appelle", nom, "et j'ai", age, "ans !")

# %% [markdown]
# > 🤖 **Demande à l'IA** :
#
# > ➡️ d'imprimer sur une ligne l'instruction suivante: je m'appelle (nom), j'ai (age) ans, et ma taille est de (taille), format f-string.

# %%
# prompt: imprime sur une ligne l'instruction suivante: je m'appelle (nom), j'ai (age) ans, et ma taille est de (taille)

nom = "Alex"  # Chaîne de caractères - string
age = 12      # Entier - integer
taille = 1.42  # Flottant - float

print(f"Je m'appelle {nom}, j'ai {age} ans, et ma taille est de {taille} m")
# Out:
# Je m'appelle Alex, j'ai 12 ans, et ma taille est de 1.42 m

# %% [markdown]
# NB: En Python, une `f-string` (ou formatted string literal) est une façon pratique d'insérer des variables ou des expressions directement dans une chaîne de caractères. Elle a été introduite avec Python 3.6.

# %% [markdown]
# ### Activité 1.1 Print - `f-string`
# Une `f-string` est une chaîne de caractères précédée de la lettre f ou F, dans laquelle on peut inclure des expressions Python entre accolades **{}**. Ces expressions sont évaluées au moment de l’exécution, et leur valeur est automatiquement insérée dans la chaîne.
#
# Demander à l’utilisateur de taper son prénom, son âge, et sa ville.
#
# Afficher une phrase comme :
#
# Bonjour, je m'appelle Alice, j'ai 12 ans et j'habite à Lyon.

# %% [markdown]
# ### Activité 1.2 - La fonction print et la concaténation

# %%
plat = "Pizza"
garniture = "anchois"
print("Je m'appelle", nom, "et j'aime la", plat, "et le garniture", garniture + "!")
# Out:
# Je m'appelle Alex et j'aime la Pizza et le garniture anchois!

# %% [markdown]
# > Utilise une f-string pour reformatter la phrase du dessus.

# %% [markdown]
# ### Activité 2 : Additionnez deux nombres
# Calculons la somme de deux nombres. Choisissez deux nombres que vous aimez !

# %%
nombre1 = 5    # Choisissez votre premier nombre
nombre2 = 10   # Choisissez votre deuxième nombre
somme = nombre1 + nombre2
print("La somme de", nombre1, "et", nombre2, "est", somme)
# Out:
# La somme de 5 et 10 est 15

# %% [markdown]
# > **Demande à l'IA** :
#
# > ➡️ reformat l'expression `print()` ci-dessus avec un format `f-string`

# %% [markdown]
# ### Activité 2.1 :  Opérations mathématiques avancées
#
# Objectif : Consolider les opérateurs.
#
# Ajoutez : Une opération avec toutes les 4 opérations
#
# - Utilisation de parenthèses
#
# - Calculer l’aire d’un rectangle

# %%
# opérations multiples avec parenthèses
a = 8
b = 3
print("Résultat :", (a + b) * 2)

# calcul de l'aire d'un rectange
longueur = 5
largeur = 4
aire = longueur * largeur
print("L'aire du rectangle est", aire)

# calcul du périmètre d'un rectangle
perimetre = 2 * (longueur + largeur)
print("Le périmètre du rectangle est", perimetre)
# Out:
# Résultat : 22
# L'aire du rectangle est 20
# Le périmètre du rectangle est 18

# %% [markdown]
# ### Activité 3 : Fonction 'input()`
#
# Essayez ce code
#
#
# ```
# nom = input("Quel est ton prénom ? ")
# pouvoir = input("Quel super-pouvoir aimerais-tu avoir ? ")
#
# print("🚀 Attention, " + nom + " se transforme en Super-" + nom.upper() + " avec le pouvoir de " + pouvoir + " !")
# print("Le monde n'est plus le même depuis son arrivée... 😎")
#
# ```

# %% [markdown]
# ### Activité 4 - Quiz interactif : Bonjour, le monde !
# Testons vos compétences ! Tapez `"Bonjour, le monde !"` exactement dans la case ci-dessous et exécutez le code. Si vous le faites correctement, vous obtiendrez un message secret !

# %%
reponse = "Tapez ici"  # Remplacez "Tapez ici" par "Bonjour, le monde !"
if reponse == "Bonjour, le monde !":
    print("Bravo ! Vous êtes une star de Python ! 🌟")
else:
    print("Oups ! Essayez de taper 'Bonjour, le monde !' exactement comme indiqué.")

# %% [markdown]
# ### Activité 5 - Défi amusant
# Essayez d'imprimer quelque chose de drôle, comme votre animal préféré ou une blague ! Modifiez ce code :

# %%
print("Votre message amusant ici !")

# %% [markdown]
# > 🤖 **Demande à l'IA** :
#
# > ➡️ "Donne-moi des idées plus drôles !"

# %% [markdown]
# ### 📝 Activité 6 - Notre Premier Programme Python

# %%
print("Bonjour ! Bienvenue dans votre premier programme Python !")

# %%
# 🔹 Step 2: Let's get your words!
name = input("Quel est ton nom? ")
animal = input("Nomme un animal: ")
food = input("Quel est ton plat préféré ? ")
place = input("Quel lieux ? ")
# Out:
# Quel est ton nom? Anne
# Nomme un animal: Mowgli
# Quel est ton plat préféré ? viande
# Quel lieux ? jardin

# %%
# 🔹 Étape 3 : Créons une histoire amusante !
print("Il était une fois, " + name + " a vu un " + animal + " manger du/de la " + food + " à/en " + place + " !")
print("Le/La " + animal + " a dit : 'Tu veux te joindre à moi ?'")
# Out:
# Il était une fois, Anne a vu un Mowgli manger du/de la viande à/en jardin !
# Le/La Mowgli a dit : 'Tu veux te joindre à moi ?'

# %% [markdown]
# Version de l'histoire modifiée pour prendre en compte les articles

# %%
def genre_article(nom):
  """Détermine le genre d'un nom (masculin ou féminin) et retourne l'article approprié."""
  # Liste de mots généralement féminins (non exhaustive)
  feminins = ["maison", "voiture", "table", "chaise", "fille", "femme", "chatte"]
  if nom.lower() in feminins:
    return "la"
  else:
    return "le"

# Demande les informations à l'utilisateur
nom = input("Quel est ton nom ? ")
animal = input("Quel animal : ")
nourriture = input("Quel est ton plat préféré ? ")
lieu = input("Quel lieu ? ")

# Construction de l'histoire
histoire = f"Il était une fois, {nom} qui a vu {genre_article(animal)} {animal} manger une {nourriture} dans un {lieu} !\n"
histoire += f"{genre_article(animal).capitalize()} {animal} a dit : 'Tu veux te joindre à moi ?'"

# Affichage de l'histoire
print(histoire)
# Out:
# Quel est ton nom ? Alice
# Quel animal : chatte
# Quel est ton plat préféré ? viande
# Quel lieu ? jardin
# Il était une fois, Alice qui a vu la chatte manger une viande dans un jardin !
# La chatte a dit : 'Tu veux te joindre à moi ?'

# %% [markdown]
# 🤖 **Demande à l'IA** :
#
# ➡️ de t'aider à ajouter d'autres questions pour rendre l'histoire encore plus idiote 🤪 !

# %%
# prompt: modifie le script ci-dessus pour rendre l'histoire en plus idiote

print("Salutations, Terriens ! Préparez-vous pour une aventure narrative hors du commun !")

# 🔹 Étape 1 : Fournissez vos mots les plus farfelus !
name = input("Quel est ton nom de code secret (ex: SuperToto) ? ")
animal = input("Nomme une créature mythique ou un animal improbable (ex: dragon rose à paillettes) : ")
food = input("Imagine un mets gargantuesque et déroutant (ex: pizza au fromage de lune) : ")
place = input("Où se déroule cette extravagance ? (ex: Planète des bonbons) : ")
adjectif = input("Un adjectif qui définit l'ambiance (ex: gluant) : ")
verbe = input("Un verbe farfelu (ex: danser la macarena) : ")

# 🔹 Étape 2 : Fabrication d'une histoire abracadabrantesque !
histoire = f"Dans un univers {adjectif}, {name}, le légendaire, a observé un {animal} cosmique {verbe} sur une planète faite de {food} !\n"
histoire += f"Ce spectacle grandiose avait lieu à {place} ! Soudain, {genre_article(animal)} {animal} a lancé un défi à {name} :\n"
histoire += f"'Tu oses me défier dans une bataille de {food} cosmique?'"

print() # cette instruction permet de sauter une ligne

# Affichage de l'histoire
print(histoire)
# Out:
# Salutations, Terriens ! Préparez-vous pour une aventure narrative hors du commun !
# Quel est ton nom de code secret (ex: SuperToto) ? supermario
# Nomme une créature mythique ou un animal improbable (ex: dragon rose à paillettes) : dragon
# Imagine un mets gargantuesque et déroutant (ex: pizza au fromage de lune) : pizza à l'ananas
# Où se déroule cette extravagance ? (ex: Planète des bonbons) : planète des bonsbons
# Un adjectif qui définit l'ambiance (ex: gluant) : gelatineux
# Un verbe farfelu (ex: danser la macarena) : danser la macarena
#
# Dans un univers gelatineux, supermario, le légendaire, a observé un dragon cosmique danser la macarena sur une planète faite de pizza à l'ananas !
# Ce spectacle grandiose avait lieu à planète des bonsbons ! Soudain, le dragon a lancé un défi à supermario :
# 'Tu oses me défier dans une bataille de pizza à l'ananas cosmique?'

# %% [markdown]
# NB: En résumé, le code évolue d'un générateur Mad Libs basique vers un générateur plus sophistiqué, intégrant de meilleures considérations grammaticales. Il démontre clairement une progression de l'apprentissage en termes de programmation, de gestion des interactions utilisateur et de manipulation de texte

# %% [markdown]
# ## 6. Conclusion
# Aujourd'hui, nous avons appris :
# - Ce qu'est Python et comment il est utilisé.
# - Comment utiliser Google Colab.
# - L'impression `print()`, les variables, les types de données et les mathématiques de base et la fonction `input()`

# %% [markdown]
# ### À suivre
# Lors de la prochaine session, nous apprendrons à prendre des décisions et à répéter des tâches avec Python. À bientôt ! 👋

# %% [markdown]
# 💡 **Astuce** : Vous voulez expérimenter ? Modifiez le code et exécutez-le à nouveau pour voir ce qui se passe !
