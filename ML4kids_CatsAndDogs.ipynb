# %% [markdown]
# <a href="https://colab.research.google.com/github/royam0820/Python/blob/main/ML4kids_CatsAndDogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from mlforkidsimages import MLforKidsImageProject

# %%
# !pip install -q tensorflow-hub

# %%
# from mlforkids import MLforKidsImageProject

project = MLforKidsImageProject("0f5dfd60-98e7-11ef-ac02-79299d1233ac767cf40e-c40d-4a21-97ce-7062b15bf66f")
# Out:
# MLFORKIDS: Downloading information about your machine learning project

# %%
project.train_model()
# Out:
# MLFORKIDS: Getting your training images to use to train your machine learning model
# ...
# 8187/8187 [==============================] - 0s 0us/step
# ...
# ERROR: Unable to download training image from https://upload.wikimedia.org/wikipedia/commons/thumb/b/b2/Bergneustadt_-_Wallstra%C3%9Fe1Museum_ex_16_ies.jpg/120px-Bergneustadt_-_Wallstra%C3%9Fe1Museum_ex_16_ies.jpg
# URL fetch failure on https://upload.wikimedia.org/wikipedia/commons/thumb/b/b2/Bergneustadt_-_Wallstra%C3%9Fe1Museum_ex_16_ies.jpg/120px-Bergneustadt_-_Wallstra%C3%9Fe1Museum_ex_16_ies.jpg: 429 -- Too many requests. Please comply with the User-Agent policy to get a higher rate limit: https://meta.wikimedia.org/wiki/User-Agent_policy
# ERROR: Skipping training image and continuing without it https://upload.wikimedia.org/wikipedia/commons/thumb/b/b2/Bergneustadt_-_Wallstra%C3%9Fe1Museum_ex_16_ies.jpg/120px-Bergneustadt_-_Wallstra%C3%9Fe1Museum_ex_16_ies.jpg
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-46048141-cfb3-421a-8ab4-59abe9360f34" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46048141-cfb3-421a-8ab4-59abe9360f34">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from IPython.display import Image, display
import matplotlib.pyplot as plt

img = plt.imread('dog9.jpg')
plt.imshow(img)
plt.axis('off')  # Hide axes
plt.title(f"Prediction: {result['class_name']} ({result['confidence']:.2f}%)")
plt.show()
