# %% [markdown]
# <a href="https://colab.research.google.com/github/royam0820/Python/blob/main/Python_Session_5_Etudiant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Camp d'Aventure Python : Session 5 - Projet Final Épique !
#
# Bienvenue à la dernière session de notre camp Python ! Aujourd’hui, on va réviser tout ce qu’on a appris et créer un projet final super cool qui combine Python et un peu d’IA. Prépare-toi à coder quelque chose d’incroyable ! 🚀
#
# ---

# %% [markdown]
# ## Ce qu’on va apprendre aujourd’hui
#
# Réviser les bases de Python (variables, boucles, conditions, listes)
#
# Créer un jeu de devinette où l’IA devine ton nombre
#
# Explorer d’autres idées de projets amusants (chatbot, générateur d’art, quiz)
#
# Montrer ton projet à tes amis !
#
# ---

# %% [markdown]
# ## 1. Petit Rappel
#
# Voici ce qu’on a appris dans les sessions précédentes :
#
# **Session 1** : Afficher des messages avec print(), utiliser des variables, faire des calculs, et poser des questions avec input().
#
# **Session 2** : Faire des choix avec if-else et répéter des tâches avec des boucles for et while.
#
# **Session 3** : Organiser des données avec des listes et dictionnaires, et découvrir l’IA avec la reconnaissance de chiffres.
#
# **Session 4** : Créer un classificateur d’images, un chatbot, et une calculatrice magique.
#
# Aujourd’hui, on va tout rassembler pour un projet final !
#
# ---

# %% [markdown]
# ## 2. Projet Final : Jeu de Devinette avec l’IA
#
# On va créer un jeu de devinette où l’IA essaie de deviner un nombre auquel tu penses (entre 1 et 100). L’IA sera intelligente et utilisera une stratégie pour deviner plus vite !
#
# Ce qu’on utilise :
#
# - Boucles pour répéter les suppositions
#
# - Conditions pour ajuster les suppositions
#
# - Listes pour garder une trace des tentatives

# %% [markdown]
# **Activité : Construire le jeu**
#
# Crée une nouvelle cellule de code dans Colab (clique sur “+ Code”) et tape :
#
#
# ```
# print("Pense à un nombre entre 1 et 100. L’IA va essayer de le deviner !")
# bas = 1
# haut = 100
# tentatives = []
#
# while True:
#     supposition = (bas + haut) // 2  # L’IA choisit le milieu
#     tentatives.append(supposition)
#     reponse = input(f"L’IA suppose : {supposition}. Est-ce correct ? (oui/trop haut/trop bas) : ")
#
#     if reponse.lower() == "oui":
#         print(f"Hourra ! L’IA a trouvé ton nombre ({supposition}) en {len(tentatives)} tentatives !")
#         print("Voici les tentatives :", tentatives)
#         break
#     elif reponse.lower() == "trop haut":
#         haut = supposition - 1
#     elif reponse.lower() == "trop bas":
#         bas = supposition + 1
#     else:
#         print("Réponds par 'oui', 'trop haut' ou 'trop bas'.")
# ```
#
# **Instructions** :
#
# - Pense à un nombre entre 1 et 100.
#
# - Réponds aux suppositions de l’IA avec “oui”, “trop haut”, ou “trop bas”.
#
# - Vérifie combien de tentatives l’IA met pour trouver ton nombre !
#
# **Défi** : Personnalise ton jeu !
#
# - Ajoute des messages amusants, comme “Je suis une IA super intelligente !” au début.
#
# - Change la plage (par exemple, de 1 à 1000).
#
# - Si l’IA trouve le nombre en moins de 5 tentatives, affiche “WOW ! Je suis un génie ! 🎉”.

# %%
# Jeu de devinette avec l'IA

# %% [markdown]
# ##  Introduction Ludique à la POO (Programmation Orientée Objet)
# Pour illustrer ce type de programmation, nous allons faire un jeu de créatures magiques avec combats (style Pokémon simple)
#
# Objectif est de :
# - Montrer ce qu’est une classe
#
# - Montrer ce qu’est un objet
#
# - Montrer l’héritage

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## POO - Les Concepts
#
#
# **Les concepts**
#
# - **Classe** : Un modèle ou un plan pour créer des objets (ex. : un plan pour construire un jouet).
# - **Objet** : Une instance d’une classe, comme un jouet fabriqué à partir du plan.
# - **Héritage** : Une classe peut "hériter" des caractéristiques d’une autre classe, comme un chiot qui hérite des traits d’un chien.

# %% [markdown]
# ### Voyant cela en code !

# %%
# La classe mère
class Dog:
    """
    Represents a dog with a name and breed.
    """
    def __init__(self, name, breed):
        """
        Initialise un nouvel objet Dog.

        Args:
            name (str): Le nom du chien.
            breed (str): La race du chien.
        """
        self.name = name
        self.breed = breed

    def bark(self):
        """
        Simule les aboiements du chien.

        Returns:
            str: Une chaîne représentant l'aboiement du chien.
        """
        return f"{self.name} barks: Woof woof!"

# Example d'utilisation (instanciation):
my_dog = Dog("Buddy", "Golden Retriever")   # nom et race du chien
print(my_dog.bark())                        # exécution de la méthode bark
# Out:
# Buddy barks: Woof woof!

# %%
# La classe fille
class GoldenRetriever(Dog):
    """
    Représente un Golden Retriever, héritant de la classe Dog.
    """
    def __init__(self, name):
        """
        Constructeur pour la classe GoldenRetriever.

        Args:
            name: le nom du Golden Retriever.
        """
        super().__init__(name, "Golden Retriever")

    def fetch(self):
        """
        Une méthode spécifique aux Golden Retrievers pour rapporter la balle.
        Returns:
            Une chaîne représentant l'action de récupération.
        """
        return f"{self.name} is fetching the ball!"

# Example usage of inheritance:
my_golden = GoldenRetriever("Goldie")
print(my_golden.bark())  # Inherited method
print(my_golden.fetch()) # Specific method
# Out:
# Goldie barks: Woof woof!
# Goldie is fetching the ball!

# %% [markdown]
# ## 3. Autres Idées de Projets
#
# Tu veux essayer autre chose ? Choisis un de ces mini-projets amusants !

# %% [markdown]
# ### Projet 1 : Chatbot Amical
#
# Crée un chatbot qui discute avec toi et réagit à tes émotions.
#
# Crée une nouvelle cellule de code et tape :
#
#
#
# ```
# print("Bienvenue chez ChatBot 3000 !")
# name = input("Comment tu t’appelles ? ")
# print(f"Salut {name} ! Je suis ton super bot Python.")
# feeling = input("Comment vas-tu aujourd’hui ? ")
#
# if feeling.lower() == "heureux":
#     print("Youpi ! Moi aussi je suis heureux ! 😊")
# elif feeling.lower() == "triste":
#     print("Oh non ! Je t’envoie des câlins virtuels ! 🤗")
# else:
#     print("D’accord ! Je suis là pour toi ! 😎")
# ```
#
# **Défi** :
#
# - Ajoute d’autres émotions (comme “fatigué” ou “excité”) avec des réponses rigolotes.
#
# - Fais dire une blague au bot si tu tapes “blague” (par exemple, “Pourquoi le robot code ? Parce qu’il veut être un pro-grammateur !”).

# %%
# Chatbot amical

# %% [markdown]
# ### Projet 2 : Générateur d’Idées d’Art IA
#
# Crée un programme qui donne des idées pour dessiner avec un style et un thème aléatoires.
#
# Crée une nouvelle cellule de code et tape :
#
#
#
# ```
# import random
#
# themes = ["espace", "océan", "jungle", "ville de robots", "monde de rêves"]
# styles = ["dessin animé", "réaliste", "pixel art", "pastel", "effrayant"]
#
# theme = random.choice(themes)
# style = random.choice(styles)
#
# print(f"Dessine ceci : Une scène {style} dans un {theme} !")
# ```
#
# **Défi** :
#
# - Ajoute 3 nouveaux thèmes (par exemple, “désert”, “montagnes”, “arc-en-ciel”).
#
# - Ajoute 3 nouveaux styles (par exemple, “aquarelle”, “néon”, “3D”).
#
# Fais en sorte que l’utilisateur puisse demander une nouvelle idée en tapant “encore”.

# %%
# générateur d'idées d'art avec l'IA

# %% [markdown]
# ### Projet 3 : Jeu de Quiz
#
# Crée un quiz avec des questions et compte les points.
#
# Crée une nouvelle cellule de code et tape :
#
# ```
# score = 0
#
# print("Bienvenue au Super Quiz !")
# answer = input("Quelle couleur obtient-on en mélangeant du rouge et du bleu ? ")
#
# if answer.lower() == "violet":
#     print("Correct !")
#     score += 1
# else:
#     print("Oups ! C’est violet.")
#
# print("Ton score :", score)
# ````
#
# **Défi** :
#
# - Ajoute 2 autres questions (par exemple, “Quelle est la capitale de la France ?” ou “Combien font 2 + 2 ?”).
#
# - Fais un message spécial si le score est 3/3, comme “Tu es un champion du quiz ! 🏆”.

# %%
# Jeu de quiz

# %% [markdown]
# # 4. Partage et Réflexion
#
# Une fois ton projet terminé :
#
# - Montre-le à un ami ou à ton prof !
#
#
#
# - Parle de :
#     - Ce que tu as aimé dans ton projet.
#
#     - Ce qui était difficile.
#
#     - Comment tu pourrais l’améliorer (par exemple, ajouter des sons ou des couleurs).
#
#
#
# **Idée** : Prends une capture d’écran de ton jeu et partage-la !

# %% [markdown]
# # 5. Ce qu’on a appris
#
# - Réviser tout ce qu’on a appris (variables, boucles, conditions, listes)
#
# - Créer un jeu de devinette avec une IA intelligente
#
# - Explorer d’autres projets amusants comme un chatbot, un générateur d’art, ou un quiz
#
#
#
# Partager tes créations avec les autres

# %% [markdown]
# # Félicitations !
#
# Tu as terminé le camp Python ! Tu sais maintenant :
#
# - Coder en Python avec des variables, boucles, et conditions
#
# - Utiliser des listes et dictionnaires
#
# - Créer des projets qui utilisent des idées d’IA
#
# - Tu es officiellement un créateur Python ! 🎉
#
#
# Pour aller plus loin :
#
#
# - Essaie d’autres projets, comme un jeu ou une appli.
#
# - Explore des outils comme Teachable Machine pour l’IA ou Scratch pour coder avec des blocs.
#
# > Astuce : Continue à t’amuser avec le code dans Colab. Si tu vois une erreur, lis le message, corrige, et réessaie !
#
# > Aussi, 🤖 Demande à l'IA : aide toi de l'IA pour résoudre ton erreur ou développer du code
