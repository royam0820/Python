# %% [markdown]
# <a href="https://colab.research.google.com/github/royam0820/Python/blob/main/Python_Session_5_Enseignant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Session 5 : Tout rassembler et construire un projet final 🤖
# Bienvenue à la session finale de notre cours sur Python assisté avec l'IA ! Aujourd'hui, nous allons réviser ce que nous avons appris et créer un projet final amusant qui combine Python et des concepts d'IA. Préparez-vous à coder quelque chose de génial ! 🚀
#
# ---

# %% [markdown]
# ## 1. Révision rapide
# Voici un récapitulatif de ce que nous avons couvert dans les sessions précédentes :
# - **Session 1** : Introduction à Python et Google Colab, avec les bases comme `print()`, les variables, les types de données et la fonction `input()`.
# - **Session 2** : Structures de contrôle (`if-else`, boucles `for` et `while`).
# - **Session 3** : Structures de données (listes, dictionnaires) et une première exploration de l'IA avec la reconnaissance de chiffres.
# - **Session 4** : Projets d'IA comme un classificateur d'images et les chatbots avec connexion par API à OpenAI et Gemini.
#
# Aujourd’hui, nous allons utiliser toutes ces compétences pour un projet final !
#
# ---

# %% [markdown]
# ## 2. Le projet final : Jeu de devinette avec l'IA
# Pour cette session, vous allez créer un **jeu de devinette de nombre** où l'IA essaie de deviner un nombre auquel vous pensez. Ce projet combine :
# - Les boucles pour répéter les suppositions.
# - Les conditions (`if-else`) pour ajuster les suppositions.
# - Une liste pour stocker les tentatives de l'IA.
#
# ---

# %% [markdown]
# ## 3. Développement du projet
#
# ### Étapes pour construire le jeu :
# 1. **Définir la plage de nombres** : L'IA devinera un nombre entre 1 et 100.
# 2. **Faire des suppositions intelligentes** : L'IA utilisera une stratégie simple (comme la recherche binaire) pour deviner.
# 3. **Demander des indices** : L'utilisateur dira si la supposition est correcte, trop haute ou trop basse.
# 4. **Stocker les tentatives** : Utilisez une liste pour suivre les suppositions de l'IA.

# %% [markdown]
# ### Code de base :

# %%
# Jeu : L'IA devine votre nombre (Recherche Binaire)
import random

print("🎮 Devine le Nombre avec l'IA !")
print("Pense à un nombre entre 1 et 100. Je vais le deviner !")

low = 1
high = 100
essais = 0

while low <= high:
    devinette = (low + high) // 2 # // est utilisé pour la division entière.  Calcule le point médian de la plage actuelle comme estimation de l'ordinateur.
    reponse = input(f"Est-ce {devinette} ? (Trop haut: 'H', Trop bas: 'B', Correct: 'O') ").upper()

    if reponse == 'O':
        print(f"Gagné en {essais} coups ! 🎉")
        break
    elif reponse == 'H':
        high = devinette - 1
        essais += 1
    elif reponse == 'B':
        low = devinette + 1
        essais += 1
    else:
        print("Réponse invalide. Utilise H, B ou O.")

if low > high:
    print("Tu as triché ? 😉")
# Out:
# 🎮 Devine le Nombre avec l'IA !
# Pense à un nombre entre 1 et 100. Je vais le deviner !
# Est-ce 50 ? (Trop haut: 'H', Trop bas: 'B', Correct: 'O') H
# Est-ce 25 ? (Trop haut: 'H', Trop bas: 'B', Correct: 'O') O
# Gagné en 1 coups ! 🎉

# %% [markdown]
# NB: Concepts de base :
# - Variables : `bas`, `haut`, `tentatives`.
# - Entrée utilisateur : `input()` pour interagir.
# - Conditions : `if/elif/else` pour donner des indices.
# - Boucles : `while` pour continuer jusqu'à ce que le joueur gagne.
# - Module `random` : Introduit une bibliothèque simple pour générer des nombres aléatoires.
#
#
# L'IA utilise un algorithme de division par deux (recherche binaire).
#
# Idéal pour te montrer comment l'IA "réfléchit" de façon optimisée.

# %% [markdown]
# ### Personnalisation :
# - Ajoutez des messages amusants (ex. : "Je suis une IA super intelligente !").
# - Modifiez la plage (ex. : 1 à 1000).
# - Affichez un message spécial si l'IA trouve le nombre en moins de 5 tentatives.
#
# ---

# %% [markdown]
# >  🤖 **Demande à l'IA** :
#
# > ➡️ de t'expliquer le code

# %% [markdown]
# #  Introduction Ludique à la POO (Programmation Orientée Objet)
# Pour illustrer ce type de programmation, nous allons faire un jeu de créatures magiques avec combats (style Pokémon simple)
#
# Objectif est de :
# - Montrer ce qu’est une classe
#
# - Montrer ce qu’est un objet
#
# - Montrer l’héritage

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## POO - Les Concepts
#
#
# **Les concepts**
#
# - **Classe** : Un modèle ou un plan pour créer des objets (ex. : un plan pour construire un jouet). Convention de nom de classe : les noms de classe commencent généralement par une lettre majuscule.
# - **Objet** : Une instance d’une classe, comme un jouet fabriqué à partir du plan.
# - **Héritage** : Une classe peut "hériter" des caractéristiques d’une autre classe, comme un chiot qui hérite des traits d’un chien.

# %% [markdown]
# ### Voyant cela en code !

# %%
# Un jeu de créatures magiques avec combats (style Pokémon simple)

# Définition classe mère - ton blueprint ou modèle
class Creature:
    # initialisation
    def __init__(self, nom, force):
        self.nom = nom
        self.force = force

    # def méthode attaquer
    def attaquer(self):
        print(f"{self.nom} attaque avec une force de {self.force} !")

# Création de l'objet
creature1 = Creature("Licorne", 10)

# Utilisation
creature1.attaquer()
# Out:
# Licorne attaque avec une force de 10 !

# %%
# Définition classe fille - la classe Dragon hérite de la classe Creature
class Dragon(Creature):
    # initialisation
    def __init__(self, nom, force, feu):
        super().__init__(nom, force)
        self.feu = feu

    # def méthode cracher_feu
    def cracher_feu(self):
        print(f"{self.nom} crache du feu avec une puissance de {self.feu} 🔥")

# Création des objets
creature1 = Creature("Licorne", 10)
dragon1 = Dragon("Drako", 15, 20)

# Utilisation
creature1.attaquer()
dragon1.attaquer()
dragon1.cracher_feu()
# Out:
# Licorne attaque avec une force de 10 !
# Drako attaque avec une force de 15 !
# Drako crache du feu avec une puissance de 20 🔥

# %% [markdown]
# # 🏁 Session 5: Final Project Launcher
#
# You've learned a lot! 🧠
# Now it’s time to **build something of your own** using Python and a little help from AI.

# %% [markdown]
# ## 🧠 Step 1: Pick your project idea
#
# Choose one!
#
# - 🤖 **Chatbot** – Talk to a friendly bot
# - 🎨 **AI Art Prompt Helper** – Get creative image ideas
# - 🎲 **Quiz Game** – Make a game with questions and answers
#
# ---

# %% [markdown]
# ## 🤖 Chatbot Starter Code

# %%
print("Welcome to ChatBot 3000!")
name = input("What's your name? ")
print("Hi " + name + "! I'm your friendly Python bot.")
feeling = input("How are you feeling today? ")

if feeling == "happy":
    print("Yay! I'm happy too! 😄")
else:
    print("Oh no! Sending you good vibes. 💖")
# Out:
# Welcome to ChatBot 3000!
# What's your name? Alice
# Hi Alice! I'm your friendly Python bot.
# How are you feeling today? happy
# Yay! I'm happy too! 😄

# %% [markdown]
# >  🤖 **Demande à l'IA** :
#
# > ➡️ Que pourrait dire d’autre mon chatbot ?

# %% [markdown]
# ## Exemple de Chatbot
# [Un exemple de Chatbot au complet](https://colab.research.google.com/drive/1H39iH2y5ycaMDUdor0p60AqrSiwtiCPT?usp=sharing)

# %% [markdown]
# ## 🎨 AI Art Prompt Helper

# %%
import random

themes = ["space", "underwater", "jungle", "robot city", "dream world"]
styles = ["cartoon", "realistic", "pixel art", "pastel", "spooky"]

theme = random.choice(themes)
style = random.choice(styles)

print("Draw this: A " + style + " scene set in a " + theme + "!")
# Out:
# Draw this: A spooky scene set in a space!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >  🤖 **Demande à l'IA** :
#
# > ➡️ Donnez-moi plus de thèmes et de styles !

# %% [markdown]
# ## Exemple de AI Art Prompt Helper
# [Un exemple de AI Art Prompt Helper](https://colab.research.google.com/drive/12lRL6RIHxx1Pvl1HpXoYEG22meiQBx6U?usp=sharing)

# %% [markdown]
# ## 🎲 Quiz Game Starter Code

# %%
score = 0

print("Welcome to the Quiz Game!")

answer = input("What color do you get when you mix red and blue? ")
if answer.lower() == "purple":
    print("Correct!")
    score += 1
else:
    print("Oops! It's purple.")

answer = input("What is the largest planet in our solar system? ")
if answer.lower() == "jupiter":
    print("Correct!")
    score += 1
else:
    print("Oops! It's Jupiter.")

answer = input("What is the capital of France? ")
if answer.lower() == "paris": # test ces valeurs 'Paris' et 'paris'
    print("Correct!")
    score += 1
else:
    print("Oops! It's Paris.")


print("Your final score:", score)
# Out:
# Welcome to the Quiz Game!
# What color do you get when you mix red and blue? blue
# Oops! It's purple.
# What is the largest planet in our solar system? moon
# Oops! It's Jupiter.
# What is the capital of France? Paris
# Correct!
# Your final score: 1

# %% [markdown]
# ➡️ Ajoute plus de questions ! Compte les points !

# %% [markdown]
# ✅ Défi Personnalisez-le script ci-dessus :
#
# Ajoutez de la couleur
#
# Posez différentes questions
#
# Rendez-le amusant
#
# Laissez l'IA vous donner des idées
#
# Lorsque vous êtes prêt, montrez-le à un ami !

# %% [markdown]
# >  🤖 **Demande à l'IA** :
#
# > ➡️ pour l'ajout de questions si en panne d'inspiration !

# %% [markdown]
# ## Exemple de Quiz Game
# [Un exemple de Jeu de Quiz sur Harry Potter](https://colab.research.google.com/drive/1r551phil3w5BURicYE_MFLtfqGAGcqJO?usp=sharing)

# %% [markdown]
# ## 4. Partage et réflexion
# Montrez votre jeu à vos amis ou à l'instructeur ! Parlez de :
# - Ce que vous avez aimé dans ce projet.
# - Les défis que vous avez rencontrés.
# - Comment vous pourriez l’améliorer (ex. : ajouter des sons, une interface graphique).
#
# ---

# %% [markdown]
# # ✨ Conclusion de nos sessions Python & IA copilote
# Au fil de ces cinq sessions, vous avez découvert les bases de Python et appris à collaborer avec une intelligence artificielle pour créer des projets passionnants.
# Bravo pour votre curiosité, votre imagination et votre persévérance ! Voici un petit résumé de notre parcours :
#
# 🧠 **Session 1** : Vous avez pris en main Google Colab, appris à afficher du texte, créer des variables, utiliser la fonction input() et manipuler les premiers types de données. Vous avez également découvert comment accéder à l’intelligence artificielle de Google (Gemini) pour lui demander des explications sur un code donné, transformer un code existant, ou encore poser une question plus générale.
#
# 🔄 **Session 2** : Vous avez compris comment faire des choix avec if, répéter des actions avec des boucles for et while, et créer des programmes interactifs.
#
# 🧺 **Session 3** : Vous avez exploré les listes et dictionnaires, et fait vos premiers pas en intelligence artificielle avec la reconnaissance de chiffres.
#
# 🤖 **Session 4** : Vous avez entraîné un modèle de classification d’images et utilisé les API d’OpenAI et de Google Gemini pour créer un chatbot intelligent.
#
# 🐉 **Session 5** : Vous avez programmé un jeu de devinette avec l’IA, découvert les bases de la programmation orientée objet (POO), avec des classes, objets et héritages et construit d'autres projets basés sur nos connaissances acquises.
#
# Ces outils sont les fondations de nombreux projets créatifs et techniques que vous pourrez continuer à explorer. Que ce soit pour coder des jeux, créer des robots intelligents ou développer des applications, vous êtes déjà sur la bonne voie.
#
# 🚀 Continuez à expérimenter, à coder, à imaginer.
# L’IA ne remplace pas la créativité humaine, elle l’amplifie. À vous de jouer !

# %% [markdown]
# ### Pour aller plus loin :
# - Essayez d'autres projets comme un jeu ou une application.
# - Explorez des outils comme **Teachable Machine** pour l'IA ou **Scratch** pour le codage visuel.
